# %% [markdown]
# ### OME-TIFF Autofluorescence Correction

# %%
import AF_utils
from AF_utils import otsu_correction, manual_correction, bcatenin_correction
# Out:
# /home/jz3553_columbia_edu/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %% [markdown]
# #### Otsu's Correction

# %%
input_dir_path = "/home/jz3553_columbia_edu/preprocessed_ome_tiff/"
output_dir_path = "/home/jz3553_columbia_edu/processed_ome_tiff/"

otsu_correction(input_dir_path, output_dir_path)

# %% [markdown]
# #### Manual Check Results: Apply Manual Thresholding or Beta-Catenine Thresholding
#
# For 10 slices (15, 18, 21, 32, 53, 56, 72, 76, 82, 94), manual check of blob correction shows unsatisfactory results. For these slices, I performed manual thresholding.
#
# 1. Slices 32, 53, 56, 76, 82 have been corrected with 99.5 percentile AF channel thresholding (removes top 0.5% of intensities).
#
# 2. Slices 15, 18, 21, 72, 94 have uneven shading. I suspect this is due to beta-catenin channel bleeding. To solve this, threshold the AF channels, then threshold the beta-catenine channel to remove gradient effects.

# %%
manual_correction(input_dir_path, output_dir_path)

# %%
bcatenin_correction(input_dir_path, output_dir_path)
